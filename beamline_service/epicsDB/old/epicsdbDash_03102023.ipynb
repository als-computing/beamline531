# %%
import dash
from dash import html, dcc, Input, Output, State, dash_table
import pandas as pd
import plotly.express as px
import pymongo
from bson.objectid import ObjectId
from epicsdb import connectMongo, pushData_list
import json

username = 'bl531'
pwd = 'bl531'

# %%
# get the latest database from cloud
def getDB(username, pwd, dbname, collectionName = 'epicsPVs'):
    client = connectMongo('bl531','bl531')
    collection = client.get_database(dbname).get_collection(collectionName)
    df = pd.DataFrame(list(collection.find()))
    return df

# %%
# load database from cloud server
client = connectMongo('bl531','bl531')
collection = client.epicsHappi.epicsPVs

# %%
# create the layout
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets,
                suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1('EPICS Database', style={'textAlign': 'Center'}),
    # interval activated once/week or when page refreshed
    dcc.Interval(id='interval_db', interval=86400000 * 7, n_intervals=0),
    html.Div(id='mongo-datatable', children=[]),

    html.Div([
        html.Div(id='pie-graph', className='five columns'),
        html.Div(id='hist-graph', className='six columns'),
    ], className='row'),
    dcc.Store(id='changed-cell')
])

# Display Datatable with data from Mongo database
@app.callback(Output('mongo-datatable', component_property='children'),
              Input('interval_db', component_property='n_intervals')
              )
def populate_datatable(n_intervals):
    # Convert the Collection (table) date to a pandas DataFrame
    df = pd.DataFrame(list(collection.find()))
    # Convert id from ObjectId to string so it can be read by DataTable
    df['_id'] = df['_id'].astype(str)

    return [
        dash_table.DataTable(
            id='our-table',
            data=df.to_dict('records'),
            # columns=[{'id':p, 'name':p, 'editable':True} for p in df if p!='_id']
            columns=[{'id': p, 'name': p, 'editable': False} if p == '_id'
                     else {'id': p, 'name': p, 'editable': True}
                     for p in df],
        ),
    ]

# store the row id and column id of the cell that was updated
app.clientside_callback(
    """
    function (input,oldinput) {
        if (oldinput != null) {
            if(JSON.stringify(input) != JSON.stringify(oldinput)) {
                for (i in Object.keys(input)) {
                    newArray = Object.values(input[i])
                    oldArray = Object.values(oldinput[i])
                    if (JSON.stringify(newArray) != JSON.stringify(oldArray)) {
                        entNew = Object.entries(input[i])
                        entOld = Object.entries(oldinput[i])
                        for (const j in entNew) {
                            if (entNew[j][1] != entOld[j][1]) {
                                changeRef = [i, entNew[j][0]] 
                                break        
                            }
                        }
                    }
                }
            }
            return changeRef
        }
    }    
    """,
    Output('changed-cell', 'data'),
    Input('our-table', 'data'),
    State('our-table', 'data_previous')
)

# Update MongoDB and create the graphs
@app.callback(
    Output("pie-graph", "children"),
    Output("hist-graph", "children"),
    Input("changed-cell", "data"),
    Input("our-table", "data"),
)
def update_d(cc, tabledata):
    if cc is None:
        # Build the Plots
        pie_fig = px.pie(tabledata, values='quantity', names='day')
        hist_fig = px.histogram(tabledata, x='department', y='quantity')
    else:
        # print(f'changed cell: {cc}')
        # print(f'Current DataTable: {tabledata}')
        x = int(cc[0])

        # update the external MongoDB
        row_id = tabledata[x]['_id']
        col_id = cc[1]
        new_cell_data = tabledata[x][col_id]
        collection.update_one({'_id': ObjectId(row_id)},
                                {"$set": {col_id: new_cell_data}})
        # Operations guide - https://docs.mongodb.com/manual/crud/#update-operations

        # pie_fig = px.pie(tabledata, values='quantity', names='day')
        # hist_fig = px.histogram(tabledata, x='department', y='quantity')

    return dcc.Graph(figure=pie_fig), dcc.Graph(figure=hist_fig)

# %%
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Mar/2023 09:42:06] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/dash/dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_3605219/509259308.py", line 11, in update_d
#     pie_fig = px.pie(tabledata, values='quantity', names='day')
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/plotly/express/_chart_types.py", line 1458, in pie
#     return make_figure(
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py", line 1933, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py", line 1405, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#   File "/home/bl531/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py", line 1207, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'names' is not the name of a column in 'data_frame'. Expected one of ['_id', 'active', 'args', 'beamline', 'creation', 'detailed_screen', 'device_class', 'documentation', 'embedded_screen', 'engineering_screen', 'functional_group', 'last_edit', 'lightpath', 'location_group', 'macros', 'name', 'parent', 'prefix', 'stand', 'system', 'type', 'z', 'unit', 'port'] but received: day
# 127.0.0.1 - - [16/Mar/2023 09:42:07] "POST /_dash-update-component HTTP/1.1" 500 -

# %%
df = getDB(username, pwd, 'epicsHappi', 'epicsPVs')
df2 = df.iloc[0:29]

# %%
df2
# Out:
#                          _id  active          args beamline  \
# 0   6412404f23d463e59014d013    True  [{{prefix}}]    5.3.1
# 1   6412405023d463e59014d014    True  [{{prefix}}]    5.3.1
# 2   6412405023d463e59014d015    True  [{{prefix}}]    5.3.1
# 3   6412405023d463e59014d016    True  [{{prefix}}]    5.3.1
# 4   6412405023d463e59014d017    True  [{{prefix}}]    5.3.1
# 5   6412405023d463e59014d018    True  [{{prefix}}]    5.3.1
# 6   6412405023d463e59014d019    True  [{{prefix}}]    5.3.1
# 7   6412405023d463e59014d01a    True  [{{prefix}}]    5.3.1
# 8   6412405023d463e59014d01b    True  [{{prefix}}]    5.3.1
# 9   6412405023d463e59014d01c    True  [{{prefix}}]    5.3.1
# 10  6412405023d463e59014d01d    True  [{{prefix}}]    5.3.1
# 11  6412405123d463e59014d01e    True  [{{prefix}}]    5.3.1
# 12  6412405123d463e59014d01f    True  [{{prefix}}]    5.3.1
# 13  6412405123d463e59014d020    True  [{{prefix}}]    5.3.1
# 14  6412405123d463e59014d021    True  [{{prefix}}]    5.3.1
# 15  6412405123d463e59014d022    True  [{{prefix}}]    5.3.1
# 16  6412405123d463e59014d023    True  [{{prefix}}]    5.3.1
# 17  6412405123d463e59014d024    True  [{{prefix}}]    5.3.1
# 18  6412405123d463e59014d025    True  [{{prefix}}]    5.3.1
# 19  6412405123d463e59014d026    True  [{{prefix}}]    5.3.1
# 20  6412405123d463e59014d027    True  [{{prefix}}]    5.3.1
# 21  6412405123d463e59014d028    True  [{{prefix}}]    5.3.1
# 22  6412405123d463e59014d029    True  [{{prefix}}]    5.3.1
# 23  6412405123d463e59014d02a    True  [{{prefix}}]    5.3.1
# 24  6412405123d463e59014d02b    True  [{{prefix}}]    5.3.1
# 25  6412405123d463e59014d02c    True  [{{prefix}}]    5.3.1
# 26  6412405223d463e59014d02d    True  [{{prefix}}]    5.3.1
# 27  6412405223d463e59014d02e    True  [{{prefix}}]    5.3.1
# 28  6412405223d463e59014d02f    True  [{{prefix}}]    5.3.1
#
#                     creation detailed_screen      device_class  \
# 0   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 1   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 2   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 3   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 4   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 5   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 6   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 7   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 8   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 9   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 10  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 11  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 12  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 13  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 14  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 15  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 16  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 17  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 18  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 19  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 20  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 21  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 22  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 23  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 24  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 25  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 26  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 27  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
# 28  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor
#
#      documentation embedded_screen engineering_screen  ... macros  \
# 0        tested AW            None               None  ...   None
# 1        tested AW            None               None  ...   None
# 2        tested aW            None               None  ...   None
# 3        tested AW            None               None  ...   None
# 4             None            None               None  ...   None
# 5             None            None               None  ...   None
# 6             None            None               None  ...   None
# 7             None            None               None  ...   None
# 8             None            None               None  ...   None
# 9             None            None               None  ...   None
# 10            None            None               None  ...   None
# 11            None            None               None  ...   None
# 12            None            None               None  ...   None
# 13            None            None               None  ...   None
# 14            None            None               None  ...   None
# 15            None            None               None  ...   None
# 16            None            None               None  ...   None
# 17            None            None               None  ...   None
# 18          tested            None               None  ...   None
# 19          tested            None               None  ...   None
# 20          tested            None               None  ...   None
# 21          tested            None               None  ...   None
# 22          tested            None               None  ...   None
# 23          tested            None               None  ...   None
# 24  tested .HOMF 1            None               None  ...   None
# 25          tested            None               None  ...   None
# 26            None            None               None  ...   None
# 27            None            None               None  ...   None
# 28            None            None               None  ...   None
#
#                          name  parent                      prefix stand  \
# 0         bl531_m101_pitch_mm    None  bl531_esp300:m101_pitch_mm  None
# 1          bl531_m101_bend_um    None   bl531_esp300:m101_bend_um  None
# 2          bl531_m101_slit_st    None   bl531_esp300:m101_slit_mm  None
# 3   bl531_saxs_mono_angle_deg    None   bl531_xps1:mono_angle_deg  None
# 4   bl531_saxs_mono_height_mm    None   bl531_xps1:mono_height_mm  None
# 5        bl531_saxs_hs_slit_A    None                     DMC01:A  None
# 6        bl531_saxs_hs_slit_B    None                     DMC01:B  None
# 7        bl531_saxs_hs_slit_C    None                     DMC01:C  None
# 8        bl531:saxs:hs_slit:D    None                     DMC01:D  None
# 9        bl531_saxs_hs_slit_E    None                     DMC01:E  None
# 10       bl531_saxs_hs_slit_F    None                     DMC01:F  None
# 11       bl531_saxs_hs_slit_G    None                     DMC01:G  None
# 12       bl531_saxs_hs_slit_H    None                     DMC01:H  None
# 13              bl531_saxs_hs    None                 micronix:m1  None
# 14   bl531_saxs_sample_slit_E    None                     DMC02:E  None
# 15   bl531_saxs_sample_slit_F    None                     DMC02:F  None
# 16   bl531_saxs_sample_slit_G    None                     DMC02:G  None
# 17   bl531_saxs_sample_slit_H    None                     DMC02:H  None
# 18        bl531_saxs_hxp_x_mm    None           bl531:hxp:c0:x_mm  None
# 19        bl531_saxs_hxp_y_mm    None           bl531:hxp:c0:y_mm  None
# 20        bl531_saxs_hxp_z_mm    None           bl531:hxp:c0:x_mm  None
# 21       bl531_saxs_hxp_u_deg    None          bl531:hxp:c0:u_deg  None
# 22       bl531_saxs_hxp_v_deg    None          bl531:hxp:c0:v_deg  None
# 23       bl531_saxs_hxp_w_deg    None          bl531:hxp:c0:w_deg  None
# 24   bl531_saxs_beamstop_x_mm    None    bl531_xps2:beamstop_x_mm  None
# 25   bl531_saxs_beamstop_y_mm    None    bl531_xps2:beamstop_y_mm  None
# 26     bl531_saxs_esp301_x_mm    None                 newport:m11  None
# 27     bl531_saxs_esp301_y_mm    None                 newport:m12  None
# 28     bl531_saxs_esp301_z_mm    None                 newport:m13  None
#
#    system       type    z unit                    port
# 0    None  OphydItem -1.0   mm        ttyUSB300, axis1
# 1    None  OphydItem -1.0   um        ttyUSB300, axis2
# 2    None  OphydItem -1.0   mm        ttyUSB300, axis3
# 3    None  OphydItem -1.0  deg    192.168.10.25, axis1
# 4    None  OphydItem -1.0   mm    192.168.10.25, axis2
# 5    None  OphydItem -1.0   mm   192.168.10.21, slit A
# 6    None  OphydItem -1.0   mm   192.168.10.21, slit B
# 7    None  OphydItem -1.0   mm   192.168.10.21, slit C
# 8    None      motor -1.0   mm   192.168.10.21, slit D
# 9    None  OphydItem -1.0   mm   192.168.10.21, slit E
# 10   None  OphydItem -1.0   mm   192.168.10.21, slit F
# 11   None  OphydItem -1.0   mm   192.168.10.21, slit G
# 12   None  OphydItem -1.0   mm   192.168.10.21, slit H
# 13   None  OphydItem -1.0   mm               ttyMMC200
# 14   None  OphydItem -1.0   mm   192.168.10.21, slit E
# 15   None  OphydItem -1.0   mm   192.168.10.21, slit F
# 16   None  OphydItem -1.0   mm   192.168.10.21, slit G
# 17   None  OphydItem -1.0   mm   192.168.10.21, slit H
# 18   None  OphydItem -1.0   mm  192.168.10.254, axis 1
# 19   None  OphydItem -1.0   mm  192.168.10.254, axis 2
# 20   None  OphydItem -1.0   mm  192.168.10.254, axis 3
# 21   None  OphydItem -1.0  deg  192.168.10.254, axis 4
# 22   None  OphydItem -1.0  deg  192.168.10.254, axis 5
# 23   None  OphydItem -1.0  deg  192.168.10.254, axis 6
# 24   None  OphydItem -1.0   mm   192.168.10.24, axis 1
# 25   None  OphydItem -1.0   mm   192.168.10.24, axis 2
# 26   None  OphydItem -1.0   mm       ttyUSB301, axis 1
# 27   None  OphydItem -1.0   mm       ttyUSB301, axis 2
# 28   None  OphydItem -1.0   mm       ttyUSB301, axis 3
#
# [29 rows x 24 columns]

# %%
# get the latest database from cloud
df = getDB(username, pwd, 'epicHappi_mod', 'epicPVs')

# %%
# push the database into cloud
pushData_list(username, pwd, 'epicsHappi_mod', df2.to_dict('records'))
# Out:
# No such fields
# Uploading bl531_m101_pitch_mm
# No such fields
# Uploading bl531_m101_bend_um
# No such fields
# Uploading bl531_m101_slit_st
# No such fields
# Uploading bl531_saxs_mono_angle_deg
# No such fields
# Uploading bl531_saxs_mono_height_mm
# No such fields
# Uploading bl531_saxs_hs_slit_A
# No such fields
# Uploading bl531_saxs_hs_slit_B
# No such fields
# Uploading bl531_saxs_hs_slit_C
# No such fields
# Uploading bl531:saxs:hs_slit:D
# No such fields
# Uploading bl531_saxs_hs_slit_E
# No such fields
# Uploading bl531_saxs_hs_slit_F
# No such fields
# Uploading bl531_saxs_hs_slit_G
# No such fields
# Uploading bl531_saxs_hs_slit_H
# No such fields
# Uploading bl531_saxs_hs
# No such fields
# Uploading bl531_saxs_sample_slit_E
# No such fields
# Uploading bl531_saxs_sample_slit_F
# No such fields
# Uploading bl531_saxs_sample_slit_G
# No such fields
# Uploading bl531_saxs_sample_slit_H
# No such fields
# Uploading bl531_saxs_hxp_x_mm
# No such fields
# Uploading bl531_saxs_hxp_y_mm
# No such fields
# Uploading bl531_saxs_hxp_z_mm
# No such fields
# Uploading bl531_saxs_hxp_u_deg
# No such fields
# Uploading bl531_saxs_hxp_v_deg
# No such fields
# Uploading bl531_saxs_hxp_w_deg
# No such fields
# Uploading bl531_saxs_beamstop_x_mm
# No such fields
# Uploading bl531_saxs_beamstop_y_mm
# No such fields
# Uploading bl531_saxs_esp301_x_mm
# No such fields
# Uploading bl531_saxs_esp301_y_mm
# No such fields
# Uploading bl531_saxs_esp301_z_mm

# %%
# # push json db 
# dbname = 'epicsHappi_mod'
# # jsonpath = './epicsDB.json'
# # with open(jsonpath, 'r') as d:
# #     pvlist = json.load(d)

# pushData(username, pwd, dbname, df)

# %%
t.drop(labels=['_id'], axis = 1)
# Out:
#                       pvname      pvname_alias motor  unit  hight  low
# 0        bl531:saxs:M1:pitch  bl531:m101:pitch   yes   deg      1    0
# 1         bl531:saxs:M1:bend   bl531:m101:bend   yes   deg      1    0
# 2         bl531:saxs:M1:slit   bl531:m101:slit   yes    mm    100    0
# 3      bl531:saxs:mono:angle   bl531:dcm:angle   yes   deg     50    0
# 4     bl531:saxs:mono:height  bl531:dcm:height   yes    mm    100    0
# 5        bl531:saxs:esp301:x       vewport:m11   yes    mm      5    0
# 6        bl531:saxs:esp301:y       vewport:m12   yes    mm      5    0
# 7        bl531:saxs:esp301:z       vewport:m13   yes    mm      5    0
# 8   bl531:saxs:camera:basler                      no  None      0    0
# 9    bl531:saxs:camera:manta                      no  None      0    0
# 10       bl531:saxs:M1:pitch  bl531:m101:pitch   yes   deg      1    0
# 11        bl531:saxs:M1:bend   bl531:m101:bend   yes   deg      1    0
# 12        bl531:saxs:M1:slit   bl531:m101:slit   yes    mm    100    0
# 13     bl531:saxs:mono:angle   bl531:dcm:angle   yes   deg     50    0
# 14    bl531:saxs:mono:height  bl531:dcm:height   yes    mm    100    0
# 15       bl531:saxs:esp301:x       vewport:m11   yes    mm      5    0
# 16       bl531:saxs:esp301:y       vewport:m12   yes    mm      5    0
# 17       bl531:saxs:esp301:z       vewport:m13   yes    mm      5    0
# 18  bl531:saxs:camera:basler                      no  None      0    0
# 19   bl531:saxs:camera:manta                      no  None      0    0

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df
# Out:
#                          _id  active          args beamline  \
# 0   6412404f23d463e59014d013    True  [{{prefix}}]    5.3.1
# 1   6412405023d463e59014d014    True  [{{prefix}}]    5.3.1
# 2   6412405023d463e59014d015    True  [{{prefix}}]    5.3.1
# 3   6412405023d463e59014d016    True  [{{prefix}}]    5.3.1
# 4   6412405023d463e59014d017    True  [{{prefix}}]    5.3.1
# 5   6412405023d463e59014d018    True  [{{prefix}}]    5.3.1
# 6   6412405023d463e59014d019    True  [{{prefix}}]    5.3.1
# 7   6412405023d463e59014d01a    True  [{{prefix}}]    5.3.1
# 8   6412405023d463e59014d01b    True  [{{prefix}}]    5.3.1
# 9   6412405023d463e59014d01c    True  [{{prefix}}]    5.3.1
# 10  6412405023d463e59014d01d    True  [{{prefix}}]    5.3.1
# 11  6412405123d463e59014d01e    True  [{{prefix}}]    5.3.1
# 12  6412405123d463e59014d01f    True  [{{prefix}}]    5.3.1
# 13  6412405123d463e59014d020    True  [{{prefix}}]    5.3.1
# 14  6412405123d463e59014d021    True  [{{prefix}}]    5.3.1
# 15  6412405123d463e59014d022    True  [{{prefix}}]    5.3.1
# 16  6412405123d463e59014d023    True  [{{prefix}}]    5.3.1
# 17  6412405123d463e59014d024    True  [{{prefix}}]    5.3.1
# 18  6412405123d463e59014d025    True  [{{prefix}}]    5.3.1
# 19  6412405123d463e59014d026    True  [{{prefix}}]    5.3.1
# 20  6412405123d463e59014d027    True  [{{prefix}}]    5.3.1
# 21  6412405123d463e59014d028    True  [{{prefix}}]    5.3.1
# 22  6412405123d463e59014d029    True  [{{prefix}}]    5.3.1
# 23  6412405123d463e59014d02a    True  [{{prefix}}]    5.3.1
# 24  6412405123d463e59014d02b    True  [{{prefix}}]    5.3.1
# 25  6412405123d463e59014d02c    True  [{{prefix}}]    5.3.1
# 26  6412405223d463e59014d02d    True  [{{prefix}}]    5.3.1
# 27  6412405223d463e59014d02e    True  [{{prefix}}]    5.3.1
# 28  6412405223d463e59014d02f    True  [{{prefix}}]    5.3.1
# 29  641241e16576e6aa3fc70637    True  [{{prefix}}]    5.3.1
# 30  641241e26576e6aa3fc70638    True  [{{prefix}}]    5.3.1
# 31  641241e26576e6aa3fc70639    True  [{{prefix}}]    5.3.1
# 32  641241e26576e6aa3fc7063a    True  [{{prefix}}]    5.3.1
# 33  641241e26576e6aa3fc7063b    True  [{{prefix}}]    5.3.1
# 34  641241e26576e6aa3fc7063c    True  [{{prefix}}]    5.3.1
# 35  641241e26576e6aa3fc7063d    True  [{{prefix}}]    5.3.1
# 36  641241e26576e6aa3fc7063e    True  [{{prefix}}]    5.3.1
# 37  641241e26576e6aa3fc7063f    True  [{{prefix}}]    5.3.1
# 38  641241e26576e6aa3fc70640    True  [{{prefix}}]    5.3.1
# 39  641241e36576e6aa3fc70641    True  [{{prefix}}]    5.3.1
# 40  641241e36576e6aa3fc70642    True  [{{prefix}}]    5.3.1
# 41  641241e36576e6aa3fc70643    True  [{{prefix}}]    5.3.1
# 42  641241e36576e6aa3fc70644    True  [{{prefix}}]    5.3.1
# 43  641241e36576e6aa3fc70645    True  [{{prefix}}]    5.3.1
# 44  641241e36576e6aa3fc70646    True  [{{prefix}}]    5.3.1
# 45  641241e36576e6aa3fc70647    True  [{{prefix}}]    5.3.1
# 46  641241e36576e6aa3fc70648    True  [{{prefix}}]    5.3.1
# 47  641241e36576e6aa3fc70649    True  [{{prefix}}]    5.3.1
# 48  641241e36576e6aa3fc7064a    True  [{{prefix}}]    5.3.1
# 49  641241e36576e6aa3fc7064b    True  [{{prefix}}]    5.3.1
# 50  641241e36576e6aa3fc7064c    True  [{{prefix}}]    5.3.1
# 51  641241e36576e6aa3fc7064d    True  [{{prefix}}]    5.3.1
# 52  641241e36576e6aa3fc7064e    True  [{{prefix}}]    5.3.1
# 53  641241e36576e6aa3fc7064f    True  [{{prefix}}]    5.3.1
# 54  641241e46576e6aa3fc70650    True  [{{prefix}}]    5.3.1
# 55  641241e46576e6aa3fc70651    True  [{{prefix}}]    5.3.1
# 56  641241e46576e6aa3fc70652    True  [{{prefix}}]    5.3.1
# 57  641241e46576e6aa3fc70653    True  [{{prefix}}]    5.3.1
#
#                     creation detailed_screen      device_class documentation  \
# 0   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 1   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 2   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 3   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 4   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 5   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 6   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 7   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 8   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 9   Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 10  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 11  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 12  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 13  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 14  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 15  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 16  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 17  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 18  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 19  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 20  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 21  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 22  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 23  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 24  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 25  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 26  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 27  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 28  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 29  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 30  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 31  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 32  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 33  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 34  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 35  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 36  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 37  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 38  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 39  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 40  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 41  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 42  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 43  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 44  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 45  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 46  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 47  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 48  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 49  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 50  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 51  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 52  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 53  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 54  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 55  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 56  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
# 57  Tue Feb 28 08:27:04 2023            None  ophyd.EpicsMotor          None
#
#    embedded_screen engineering_screen  ... macros                       name  \
# 0             None               None  ...   None        bl531_m101_pitch_mm
# 1             None               None  ...   None         bl531_m101_bend_um
# 2             None               None  ...   None         bl531_m101_slit_st
# 3             None               None  ...   None  bl531_saxs_mono_angle_deg
# 4             None               None  ...   None  bl531_saxs_mono_height_mm
# 5             None               None  ...   None       bl531_saxs_hs_slit_A
# 6             None               None  ...   None       bl531_saxs_hs_slit_B
# 7             None               None  ...   None       bl531_saxs_hs_slit_C
# 8             None               None  ...   None       bl531:saxs:hs_slit:D
# 9             None               None  ...   None       bl531_saxs_hs_slit_E
# 10            None               None  ...   None       bl531_saxs_hs_slit_F
# 11            None               None  ...   None       bl531_saxs_hs_slit_G
# 12            None               None  ...   None       bl531_saxs_hs_slit_H
# 13            None               None  ...   None              bl531_saxs_hs
# 14            None               None  ...   None   bl531_saxs_sample_slit_E
# 15            None               None  ...   None   bl531_saxs_sample_slit_F
# 16            None               None  ...   None   bl531_saxs_sample_slit_G
# 17            None               None  ...   None   bl531_saxs_sample_slit_H
# 18            None               None  ...   None        bl531_saxs_hxp_x_mm
# 19            None               None  ...   None        bl531_saxs_hxp_y_mm
# 20            None               None  ...   None        bl531_saxs_hxp_z_mm
# 21            None               None  ...   None       bl531_saxs_hxp_u_deg
# 22            None               None  ...   None       bl531_saxs_hxp_v_deg
# 23            None               None  ...   None       bl531_saxs_hxp_w_deg
# 24            None               None  ...   None   bl531_saxs_beamstop_x_mm
# 25            None               None  ...   None   bl531_saxs_beamstop_y_mm
# 26            None               None  ...   None     bl531_saxs_esp301_x_mm
# 27            None               None  ...   None     bl531_saxs_esp301_y_mm
# 28            None               None  ...   None     bl531_saxs_esp301_z_mm
# 29            None               None  ...   None        bl531_m101_pitch_mm
# 30            None               None  ...   None         bl531_m101_bend_um
# 31            None               None  ...   None         bl531_m101_slit_st
# 32            None               None  ...   None  bl531_saxs_mono_angle_deg
# 33            None               None  ...   None  bl531_saxs_mono_height_mm
# 34            None               None  ...   None       bl531_saxs_hs_slit_A
# 35            None               None  ...   None       bl531_saxs_hs_slit_B
# 36            None               None  ...   None       bl531_saxs_hs_slit_C
# 37            None               None  ...   None       bl531:saxs:hs_slit:D
# 38            None               None  ...   None       bl531_saxs_hs_slit_E
# 39            None               None  ...   None       bl531_saxs_hs_slit_F
# 40            None               None  ...   None       bl531_saxs_hs_slit_G
# 41            None               None  ...   None       bl531_saxs_hs_slit_H
# 42            None               None  ...   None              bl531_saxs_hs
# 43            None               None  ...   None   bl531_saxs_sample_slit_E
# 44            None               None  ...   None   bl531_saxs_sample_slit_F
# 45            None               None  ...   None   bl531_saxs_sample_slit_G
# 46            None               None  ...   None   bl531_saxs_sample_slit_H
# 47            None               None  ...   None        bl531_saxs_hxp_x_mm
# 48            None               None  ...   None        bl531_saxs_hxp_y_mm
# 49            None               None  ...   None        bl531_saxs_hxp_z_mm
# 50            None               None  ...   None       bl531_saxs_hxp_u_deg
# 51            None               None  ...   None       bl531_saxs_hxp_v_deg
# 52            None               None  ...   None       bl531_saxs_hxp_w_deg
# 53            None               None  ...   None   bl531_saxs_beamstop_x_mm
# 54            None               None  ...   None   bl531_saxs_beamstop_y_mm
# 55            None               None  ...   None     bl531_saxs_esp301_x_mm
# 56            None               None  ...   None     bl531_saxs_esp301_y_mm
# 57            None               None  ...   None     bl531_saxs_esp301_z_mm
#
#     parent                      prefix stand system       type    z unit  \
# 0     None  bl531_esp300:m101_pitch_mm  None   None  OphydItem -1.0   mm
# 1     None   bl531_esp300:m101_bend_um  None   None  OphydItem -1.0   um
# 2     None   bl531_esp300:m101_slit_mm  None   None  OphydItem -1.0   mm
# 3     None                      IOC:m1  None   None  OphydItem -1.0  deg
# 4     None                      IOC:m2  None   None  OphydItem -1.0   mm
# 5     None                     DMC01:A  None   None  OphydItem -1.0   mm
# 6     None                     DMC01:B  None   None  OphydItem -1.0   mm
# 7     None                     DMC01:C  None   None  OphydItem -1.0   mm
# 8     None                     DMC01:D  None   None      motor -1.0   mm
# 9     None                     DMC01:E  None   None  OphydItem -1.0   mm
# 10    None                     DMC01:F  None   None  OphydItem -1.0   mm
# 11    None                     DMC01:G  None   None  OphydItem -1.0   mm
# 12    None                     DMC01:H  None   None  OphydItem -1.0   mm
# 13    None                 micronix:m1  None   None  OphydItem -1.0   mm
# 14    None                     DMC02:E  None   None  OphydItem -1.0   mm
# 15    None                     DMC02:F  None   None  OphydItem -1.0   mm
# 16    None                     DMC02:G  None   None  OphydItem -1.0   mm
# 17    None                     DMC02:H  None   None  OphydItem -1.0   mm
# 18    None             BL531:hxp:c0:m1  None   None  OphydItem -1.0   mm
# 19    None             BL531:hxp:c0:m2  None   None  OphydItem -1.0   mm
# 20    None             BL531:hxp:c0:m3  None   None  OphydItem -1.0   mm
# 21    None             BL531:hxp:c0:m4  None   None  OphydItem -1.0  deg
# 22    None             BL531:hxp:c0:m5  None   None  OphydItem -1.0  deg
# 23    None             BL531:hxp:c0:m6  None   None  OphydItem -1.0  deg
# 24    None          bl531:beamstopx_mm  None   None  OphydItem -1.0   mm
# 25    None          bl531:beamstopy_mm  None   None  OphydItem -1.0   mm
# 26    None                 newport:m11  None   None  OphydItem -1.0   mm
# 27    None                 newport:m12  None   None  OphydItem -1.0   mm
# 28    None                 newport:m13  None   None  OphydItem -1.0   mm
# 29    None                 newport:m21  None   None  OphydItem -1.0   mm
# 30    None                 newport:m22  None   None  OphydItem -1.0   mm
# 31    None                 newport:m23  None   None  OphydItem -1.0   st
# 32    None                      IOC:m1  None   None  OphydItem -1.0  deg
# 33    None                      IOC:m2  None   None  OphydItem -1.0   mm
# 34    None                     DMC01:A  None   None  OphydItem -1.0   mm
# 35    None                     DMC01:B  None   None  OphydItem -1.0   mm
# 36    None                     DMC01:C  None   None  OphydItem -1.0   mm
# 37    None                     DMC01:D  None   None      motor -1.0   mm
# 38    None                     DMC01:E  None   None  OphydItem -1.0   mm
# 39    None                     DMC01:F  None   None  OphydItem -1.0   mm
# 40    None                     DMC01:G  None   None  OphydItem -1.0   mm
# 41    None                     DMC01:H  None   None  OphydItem -1.0   mm
# 42    None                 micronix:m1  None   None  OphydItem -1.0   mm
# 43    None                     DMC02:E  None   None  OphydItem -1.0   mm
# 44    None                     DMC02:F  None   None  OphydItem -1.0   mm
# 45    None                     DMC02:G  None   None  OphydItem -1.0   mm
# 46    None                     DMC02:H  None   None  OphydItem -1.0   mm
# 47    None             BL531:hxp:c0:m1  None   None  OphydItem -1.0   mm
# 48    None             BL531:hxp:c0:m2  None   None  OphydItem -1.0   mm
# 49    None             BL531:hxp:c0:m3  None   None  OphydItem -1.0   mm
# 50    None             BL531:hxp:c0:m4  None   None  OphydItem -1.0  deg
# 51    None             BL531:hxp:c0:m5  None   None  OphydItem -1.0  deg
# 52    None             BL531:hxp:c0:m6  None   None  OphydItem -1.0  deg
# 53    None          bl531:beamstopx_mm  None   None  OphydItem -1.0   mm
# 54    None          bl531:beamstopy_mm  None   None  OphydItem -1.0   mm
# 55    None                 newport:m11  None   None  OphydItem -1.0   mm
# 56    None                 newport:m12  None   None  OphydItem -1.0   mm
# 57    None                 newport:m13  None   None  OphydItem -1.0   mm
#
#                       port
# 0         ttyUSB300, axis1
# 1         ttyUSB300, axis2
# 2         ttyUSB300, axis3
# 3     192.168.10.25, axis1
# 4     192.168.10.25, axis2
# 5    192.168.10.21, slit A
# 6    192.168.10.21, slit B
# 7    192.168.10.21, slit C
# 8    192.168.10.21, slit D
# 9    192.168.10.21, slit E
# 10   192.168.10.21, slit F
# 11   192.168.10.21, slit G
# 12   192.168.10.21, slit H
# 13               ttyMMC200
# 14   192.168.10.21, slit E
# 15   192.168.10.21, slit F
# 16   192.168.10.21, slit G
# 17   192.168.10.21, slit H
# 18  192.168.10.254, axis 1
# 19  192.168.10.254, axis 2
# 20  192.168.10.254, axis 3
# 21  192.168.10.254, axis 4
# 22  192.168.10.254, axis 5
# 23  192.168.10.254, axis 6
# 24   192.168.10.24, axis 1
# 25   192.168.10.24, axis 2
# 26       ttyUSB301, axis 1
# 27       ttyUSB301, axis 2
# 28       ttyUSB301, axis 3
# 29        ttyUSB300, axis1
# 30        ttyUSB300, axis2
# 31        ttyUSB300, axis3
# 32    192.168.10.25, axis1
# 33    192.168.10.25, axis2
# 34   192.168.10.21, slit A
# 35   192.168.10.21, slit B
# 36   192.168.10.21, slit C
# 37   192.168.10.21, slit D
# 38   192.168.10.21, slit E
# 39   192.168.10.21, slit F
# 40   192.168.10.21, slit G
# 41   192.168.10.21, slit H
# 42               ttyMMC200
# 43   192.168.10.21, slit E
# 44   192.168.10.21, slit F
# 45   192.168.10.21, slit G
# 46   192.168.10.21, slit H
# 47  192.168.10.254, axis 1
# 48  192.168.10.254, axis 2
# 49  192.168.10.254, axis 3
# 50  192.168.10.254, axis 4
# 51  192.168.10.254, axis 5
# 52  192.168.10.254, axis 6
# 53   192.168.10.24, axis 1
# 54   192.168.10.24, axis 2
# 55       ttyUSB301, axis 1
# 56       ttyUSB301, axis 2
# 57       ttyUSB301, axis 3
#
# [58 rows x 24 columns]
